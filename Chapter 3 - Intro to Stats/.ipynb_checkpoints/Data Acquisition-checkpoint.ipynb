# %% [markdown]
# # Types of Data
# ## A. Qualitative Data
# ### 1. Nominal Data
# Used to label variables without any order or quantitative value
# ### 2. Ordinal Data
# Natural ordering where a number is present in some kind of order by their position on the scale. These data are used for observation like customer satisfaction, happiness, etc., but we can’t do any arithmetical tasks on them.
# ## B. Quantitative Data
# ### 1. Discrete Data
# The term discrete means distinct or separate. The discrete data contain the values that fall under integers or whole numbers. The total number of students in a class is an example of discrete data. These data can’t be broken into decimal or fraction values.
# ### 2. Continuous Data
# Continuous data are in the form of fractional numbers. It can be the version of an android phone, the height of a person, the length of an object, etc. Continuous data represents information that can be divided into smaller levels. The continuous variable can take any value within a range.

# %% [markdown]
# ![types-of-data.png](attachment:types-of-data.png)

# %% [markdown]
# ![Screenshot%20from%202023-03-06%2011-16-03.png](attachment:Screenshot%20from%202023-03-06%2011-16-03.png)

# %% [markdown]
# Some readings
# 1. 4 Types Of Data – Nominal, Ordinal, Discrete and Continuous - https://www.mygreatlearning.com/blog/types-of-data/

# %%
#Open days_of_week.txt file

myfile = open("days_of_week.txt","r")
print(myfile.read())
# Out:
# Monday      1
# Tuesday     2
# Wednesday   3
# Thursday    4
# Friday      5
# Saturday    6
# Sunday      7

# %%
#Open days_of_week.txt file but only the first char the txt file

myfile = open("days_of_week.txt","r")
print(myfile.read(1))
# Out:
# M

# %%
myfile = open("days_of_week.txt","r")
for k in myfile:
    print(myfile.read())
# Out:
# Tuesday     2
# Wednesday   3
# Thursday    4
# Friday      5
# Saturday    6
# Sunday      7

# %%
#Manipulating the output using counter when opening a txt file

myfile = open("days_of_week.txt","r")

for k in myfile:
    print(k)
    print("Reading observation from our dataset: " + k)
# Out:
# Monday      1
#
# Reading observation from our dataset: Monday      1
#
# Tuesday     2
#
# Reading observation from our dataset: Tuesday     2
#
# Wednesday   3
#
# Reading observation from our dataset: Wednesday   3
#
# Thursday    4
#
# Reading observation from our dataset: Thursday    4
#
# Friday      5
#
# Reading observation from our dataset: Friday      5
#
# Saturday    6
#
# Reading observation from our dataset: Saturday    6
#
# Sunday      7
# Reading observation from our dataset: Sunday      7

# %%
myfile = open("days_of_week.txt")

# %%
import pandas as pd
xl_file = pd.ExcelFile("trigonometric_functions.xlsx")
trig_values = xl_file.parse('Sheet1')
print(trig_values)
# Out:
#      Angle in degrees          Sine    Cosine      Tangente
# 0                   0  0.000000e+00  1.000000  0.000000e+00
# 1                   1  1.745241e-02  0.999848  1.745506e-02
# 2                   2  3.489950e-02  0.999391  3.492077e-02
# 3                   3  5.233596e-02  0.998630  5.240778e-02
# 4                   4  6.975647e-02  0.997564  6.992681e-02
# ..                ...           ...       ...           ...
# 356               356 -6.975647e-02  0.997564 -6.992681e-02
# 357               357 -5.233596e-02  0.998630 -5.240778e-02
# 358               358 -3.489950e-02  0.999391 -3.492077e-02
# 359               359 -1.745241e-02  0.999848 -1.745506e-02
# 360               360 -2.450297e-16  1.000000 -2.450297e-16
#
# [361 rows x 4 columns]

# %%
import pandas as pd 
data1 = pd.read_csv("example_csv.csv")
data1.head()
# Out:
#      name  age        designation
# 0    John   50            Manager
# 1   Julia   40  Assistant Manager
# 2     Tom   30         Programmer
# 3  Sophia   25         Accountant

# %%
import pandas as pd 
data1 = pd.read_csv("example_csv.csv")
data1.head(3)#Returns the number of lines specified by the integer input
# Out:
#     name  age        designation
# 0   John   50            Manager
# 1  Julia   40  Assistant Manager
# 2    Tom   30         Programmer

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [11], line 2
#       1 data2 = pd.ExcelFile("trigonometric_functions.xlsx")
# ----> 2 data2.head(6)
#
# AttributeError: 'ExcelFile' object has no attribute 'head'
